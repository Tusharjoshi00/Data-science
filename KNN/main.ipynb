# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("Crop_recommendation.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
label = df.groupby("label")
label

# %%
label.get_group("rice")
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# ..  ..  ..  ..          ...        ...       ...         ...   ...
# 95  88  46  42    22.683191  83.463583  6.604993  194.265172  rice
# 96  93  47  37    21.533463  82.140041  6.500343  295.924880  rice
# 97  60  55  45    21.408658  83.329319  5.935745  287.576694  rice
# 98  78  35  44    26.543481  84.673536  7.072656  183.622266  rice
# 99  65  37  40    23.359054  83.595123  5.333323  188.413665  rice
#
# [100 rows x 8 columns]

# %%
label[["humidity"]].mean()
# Out:
#               humidity
# label
# apple        92.333383
# banana       80.358123
# blackgram    65.118426
# chickpea     16.860439
# coconut      94.844272
# coffee       58.869846
# cotton       79.843474
# grapes       81.875228
# jute         79.639864
# kidneybeans  21.605357
# lentil       64.804785
# maize        65.092249
# mango        50.156573
# mothbeans    53.160418
# mungbean     85.499975
# muskmelon    92.342802
# orange       92.170209
# papaya       92.403388
# pigeonpeas   48.061633
# pomegranate  90.125504
# rice         82.272822
# watermelon   85.160375

# %%
lables = list(label.mean().index)
lables
# Out:
# ['apple',
#  'banana',
#  'blackgram',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'kidneybeans',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'mungbean',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'pomegranate',
#  'rice',
#  'watermelon']

# %%
nitrogen = list(label[["N"]].mean().values.ravel())
nitrogen
# Out:
# [np.float64(20.8),
#  np.float64(100.23),
#  np.float64(40.02),
#  np.float64(40.09),
#  np.float64(21.98),
#  np.float64(101.2),
#  np.float64(117.77),
#  np.float64(23.18),
#  np.float64(78.4),
#  np.float64(20.75),
#  np.float64(18.77),
#  np.float64(77.76),
#  np.float64(20.07),
#  np.float64(21.44),
#  np.float64(20.99),
#  np.float64(100.32),
#  np.float64(19.58),
#  np.float64(49.88),
#  np.float64(20.73),
#  np.float64(18.87),
#  np.float64(79.89),
#  np.float64(99.42)]

# %%
plt.bar(x =lables, height =nitrogen , ec ="k")
plt.xticks(rotation=50)
plt.show()

# %%
x=df.drop("label",axis =1)

# %%
##standard scaler ----normalise ----outliers se deal krne k liye
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_transformed = sc.fit_transform(x)
x_transformed.shape
# Out:
# (2200, 7)

# %%
desc = pd.DataFrame(x_transformed).describe()
desc.head()
# Out:
#                   0             1             2             3             4  \
# count  2.200000e+03  2.200000e+03  2.200000e+03  2.200000e+03  2.200000e+03
# mean  -1.033517e-16  5.167584e-17 -5.167584e-17  3.875688e-16 -1.808654e-16
# std    1.000227e+00  1.000227e+00  1.000227e+00  1.000227e+00  1.000227e+00
# min   -1.369636e+00 -1.466498e+00 -8.521355e-01 -3.316592e+00 -2.570842e+00
# 25%   -8.006682e-01 -7.690712e-01 -5.559060e-01 -5.623337e-01 -5.040636e-01
#
#                   5             6
# count  2.200000e+03  2.200000e+03
# mean  -1.291896e-16  1.550275e-16
# std    1.000227e+00  1.000227e+00
# min   -3.831577e+00 -1.515170e+00
# 25%   -6.433340e-01 -7.081870e-01

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
desc_formatted = desc.applymap(lambda x:f"{int(x):d}")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_25728\2922687664.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   desc_formatted = desc.applymap(lambda x:f"{int(x):d}")

# %%
from sklearn.cluster import KMeans
kmeans =KMeans()
kmeans.fit(x_transformed)
# Out:
# KMeans()

# %%
label = kmeans.labels_

# %%
df["cluster_8"] =label

# %%
df["cluster_8"].value_counts()
# Out:
# cluster_8
# 1    525
# 4    428
# 0    338
# 2    289
# 7    222
# 5    198
# 6    159
# 3     41
# Name: count, dtype: int64

# %%
df[df["label"]=="rice"]["cluster_8"].value_counts()
# Out:
# cluster_8
# 0    100
# Name: count, dtype: int64

# %%
df[df["cluster_8"]== 1 ]["label"].value_counts()
# Out:
# label
# banana        100
# watermelon    100
# muskmelon     100
# cotton        100
# maize          96
# coffee         21
# papaya          8
# Name: count, dtype: int64

# %%
## met
from sklearn.metrics import silhouette_score
## range ==== -1 to 1
silhouette_score(x_transformed,label)
# Out:
# 0.31215458470002927

# %%
kmeans.inertia_
# Out:
# 5076.497224116285

# %%
WCSS = {}
for i in range(5,51):
    kmeans = KMeans(n_clusters= i)
    kmeans.fit(x_transformed)
    WCSS[i] =kmeans.inertia_

# %%
WCSS
# Out:
# {5: 6913.400615142733,
#  6: 6061.095967891577,
#  7: 5720.495547397318,
#  8: 4879.366567480649,
#  9: 4605.276254467249,
#  10: 4110.746544589909,
#  11: 3845.180493730446,
#  12: 3841.7017926437143,
#  13: 3384.5510369444587,
#  14: 3364.998467488038,
#  15: 3185.9744283045106,
#  16: 2909.0134658374736,
#  17: 2870.553541179188,
#  18: 2627.8614301613793,
#  19: 2578.258051642405,
#  20: 2478.0994228562395,
#  21: 2329.019288553373,
#  22: 2237.647134394123,
#  23: 2170.680102398188,
#  24: 2106.881950556084,
#  25: 2089.952401740118,
#  26: 1942.121024409308,
#  27: 1992.0169342603267,
#  28: 1812.4675369896734,
#  29: 1778.6966383708916,
#  30: 1761.1707242234675,
#  31: 1708.290994246644,
#  32: 1684.3693056861014,
#  33: 1667.1807755523505,
#  34: 1627.002384414192,
#  35: 1583.2351828422657,
#  36: 1607.065779375957,
#  37: 1521.0371030239426,
#  38: 1488.8851794491334,
#  39: 1439.8965845882533,
#  40: 1430.4599655570883,
#  41: 1434.668466798872,
#  42: 1387.2224614729491,
#  43: 1355.8111582152044,
#  44: 1317.789815198049,
#  45: 1332.94655518274,
#  46: 1296.554516160561,
#  47: 1328.5378249309442,
#  48: 1273.752899337408,
#  49: 1272.384802560061,
#  50: 1262.6577218947373}

# %%
plt.figure(figsize = (20,8))
plt.plot(WCSS.keys(), WCSS.values(),marker ="o")
#add a line
plt.xticks(list(WCSS.keys()))
plt.grid(True)
plt.show()

# %%
import joblib
joblib.dump(kmeans, "crop_reco_kmeans.lb" )
# Out:
# ['crop_reco_kmeans.lb']

# %%
joblib.dump(sc,"scaler.lb")
# Out:
# ['scaler.lb']

# %%
joblib.dump(df , "crop_reco_df.lb")
# Out:
# ['crop_reco_df.lb']
