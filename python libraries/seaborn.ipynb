# %%
##seaborn is a library for making statistical
#graphics in python . it is built on top of 
#matplotlib and is heavily inspired by R's ggplot2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.plot(df["total_bill"])
plt.show()

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(df["total_bill"])
sns.scatterplot(x="total_bill",y ="tip",data=df)
plt.title("scatterplot")
plt.show()

# %%
sns.histplot(df["total_bill"],color="red",edgecolor="blue")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>
